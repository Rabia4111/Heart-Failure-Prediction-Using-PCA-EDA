# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r'C:\Users\Administrator\Desktop\Exploratory Data Analysis\Heart Failure Prediction EDA\Heart-Failure-Prediction-Using-PCA-EDA\dataset\heart.csv') 

numerical_features = ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']

# Plot histograms for numerical features
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_features):
    plt.subplot(2, 3, i + 1)
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
import numpy as np

df['Cholesterol'] = df['Cholesterol'].replace(0, np.nan)

median_chol = df['Cholesterol'].median()
df['Cholesterol'] = df['Cholesterol'].fillna(median_chol)

df['Oldpeak'] = df['Oldpeak'].apply(lambda x: 3 if x > 3 else x)

# %%
import numpy as np

df['Cholesterol'] = df['Cholesterol'].replace(0, np.nan)

median_chol = df['Cholesterol'].median()
df['Cholesterol'] = df['Cholesterol'].fillna(median_chol)

df['Oldpeak'] = df['Oldpeak'].apply(lambda x: 3 if x > 3 else x)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

categorical_features = ['Sex', 'ChestPainType', 'FastingBS', 'RestingECG', 'ExerciseAngina', 'ST_Slope']

fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 12))
axes = axes.flatten()

for i, col in enumerate(categorical_features):
    sns.countplot(data=df, x=col, hue='HeartDisease', ax=axes[i], palette='Set2')
    axes[i].set_title(f'{col} vs HeartDisease')
    axes[i].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numerical_features = ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak']

plt.figure(figsize=(16, 12))
for i, col in enumerate(numerical_features, 1):
    plt.subplot(3, 2, i)
    sns.boxplot(x='HeartDisease', y=col, data=df, palette='Set2')
    plt.title(f'{col} vs HeartDisease')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10812\2285708995.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='HeartDisease', y=col, data=df, palette='Set2')
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10812\2285708995.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='HeartDisease', y=col, data=df, palette='Set2')
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10812\2285708995.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='HeartDisease', y=col, data=df, palette='Set2')
# ...

# %%
import numpy as np

numeric_df = df.select_dtypes(include=[np.number])

corr = numeric_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix (Numerical Features)')
plt.show()
